# %%
import pandas as pd

# %%
data = pd.read_html('https://en.wikipedia.org/wiki/Goods_and_Services_Tax_(India)_Revenue_Statistics')
data
# Out:
# [             Month                             2022-23               \
#               Month                         Collections M-O-M Change
#  0            April   ₹167,540 crore (US$21 billion)[2]          NaN
#  1              May   ₹140,885 crore (US$18 billion)[7]          NaN
#  2             June  ₹144,616 crore (US$18 billion)[10]          NaN
#  3             July                              148996          NaN
#  4           August                                 NaN          NaN
#  5        September                                 NaN          NaN
#  6          October                                 NaN          NaN
#  7         November                                 NaN          NaN
#  8         December                                 NaN          NaN
#  9          January                                 NaN          NaN
#  10        February                                 NaN          NaN
#  11           March                                 NaN          NaN
# ...

# %%
len(data)
# Out:
# 43

# %%
data[2]
# Out:
#         Month     2021-22                                         2020-21  \
#         Month Collections M-O-M Change                        Collections
# 0       April         NaN          NaN                                NaN
# 1         May         NaN          NaN                                NaN
# 2        June         NaN          NaN     ₹49 crore (US$6.1 million)[33]
# 3        July         NaN          NaN     ₹33 crore (US$4.1 million)[34]
# 4      August         NaN          NaN     ₹35 crore (US$4.4 million)[35]
# 5   September         NaN          NaN     ₹35 crore (US$4.4 million)[36]
# 6     October         NaN          NaN      ₹98 crore (US$12 million)[37]
# 7    November         NaN          NaN     ₹60 crore (US$7.5 million)[22]
# 8    December         NaN          NaN     ₹46 crore (US$5.8 million)[24]
# 9     January         NaN          NaN                                NaN
# 10   February         NaN          NaN  ₹61.36 crore (US$7.7 million)[30]
# ...
